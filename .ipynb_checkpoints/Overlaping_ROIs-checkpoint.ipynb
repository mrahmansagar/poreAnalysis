# %%
import os 

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm 
from tkinter import Tcl

import tifffile

from PIL import Image


from scipy import ndimage as nd

import pypore3d 
from pypore3d import *
from pypore3d.p3dFiltPy import *
# from pypore3d.p3dBlobPy import *
# from pypore3d.p3dSkelPy import *
# from pypore3d.p3dSITKPy import *

import os
 
from poreUtils import *

from scipy.ndimage import distance_transform_edt

# %%
# Path to the slices 
data_dir = 'D:\sagar\Data\MD_1264_A2_1_Z3.3mm\slices'
tiffs = os.listdir(data_dir)

# %%
import gc 
gc.collect()
# Out:
# 2924

# %%
# Reading all the slices in a Volume 
vol = np.empty(shape=(1700, 3691, 3691), dtype=np.uint8)
for i, fname in enumerate(tqdm(tiffs)):
    im = Image.open(os.path.join(data_dir, fname))
    imarray = np.array(im)
    imarray = np.clip(imarray, 0.0005, 0.003)
    imarray = norm8bit(imarray)
    vol[i, :, :] = imarray
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1700/1700 [12:05<00:00,  2.34it/s]

# %%
# Reading the image 
img_path = 'D:\\sagar\\Data\\MD_1264_A2_1_Z3.3mm\\result\\600-900x1000-1300x1600-1900_8bit.raw'

x, y, z = 300, 300, 300

volc = py_p3dReadRaw8(img_path, x, y, z)
# Appying Median filter for removing noise
volc = py_p3dMedianFilter8(volc, x, y, z, width=3)
# convert it to numpy array for manual thresholding and a bit processing which are easy in numpy array
roi = swigObjt2uint8Array(volc, x, y, z)

# %%
plt.figure(figsize=(16,16))

plt.imshow(vol[650, :, :], cmap='gray')
plt.show()

# %%
roi_mask = np.empty(shape=vol.shape[1:])

# %%
roi_mask[:] = np.nan

# %%
from scipy.ndimage import distance_transform_edt

# %%
sliceNo = 650
slice_at_roi = 650-600

th_roi = roi > 40
#th_vol = nd.binary_closing(th_vol, np.ones((3,3,3)))
dis3d = distance_transform_edt(th_roi)
msk = dis3d[slice_at_roi, ...] > 1
dist_img = msk*roi

# %%
roi_mask[1000:1300, 1600:1900] = dist_img[slice_at_roi, :, :]

# %%
plt.figure(figsize=(16,16))

plt.imshow(vol[sliceNo], cmap='gray')#, alpha=0.5)
# cbar = plt.colorbar(orientation='horizontal')
# cbar.set_label('Title (Unit)')

plt.imshow(roi_mask, cmap='jet', alpha=0.5)
cbar = plt.colorbar()
cbar.set_label('Title (Unit)')

plt.show()

# %%
from glob import glob

# %%
root_dir = 'D:\sagar\Data'
scan = 'MD_1264_A2_1_Z3.3mm'
scan_path = os.path.join(root_dir, scan, 'slices')
roi_path = os.path.join(root_dir, scan, 'result')

# %%
# Reading the original volume with clipping and converted to 8bit 
tiffs = os.listdir(scan_path)

vol = np.empty(shape=(1700, 3691, 3691), dtype=np.uint8)
for i, fname in enumerate(tqdm(tiffs)):
    im = Image.open(os.path.join(data_dir, fname))
    imarray = np.array(im)
    imarray = np.clip(imarray, 0.0005, 0.003)
    imarray = norm8bit(imarray)
    vol[i, :, :] = imarray
# Out:
# 'D:\\sagar\\Data\\MD_1264_A2_1_Z3.3mm\\results'

# %%
# Available ROIs
rois = glob(os.path.join(roi_path, '*.raw'))

# %%
silceNo = 850

# %%
a.split('\\')[-1].split('_8bit.raw')[0]
# Out:
# '1000-1300x1000-1300x2000-2300'

# %%
# get the roi in this range 
def roi_in_range(sliceNo, roiList):

# %%
sliceNo = 1400
selected_rois = []
for r in rois:
    if int(r.split('\\')[-1].split('_8bit.raw')[0].split('-')[0]) <= sliceNo:
        selected_rois.append(r)
        
range_min = int(selected_rois[0].split('\\')[-1].split('_8bit.raw')[0].split('-')[0])
range_max = int(selected_rois[0].split('\\')[-1].split('_8bit.raw')[0].split('-')[1].split('x')[0])
